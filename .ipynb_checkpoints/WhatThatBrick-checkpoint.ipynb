# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import pandas as pd
import streamlit as st

# %%
base_dir = "Lego/"
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# %%
# colors_df = pd.read_csv("colors.csv")
parts_df = pd.read_csv("parts.csv")
# sets_df = pd.read_csv("sets.csv") 
# inventories_df = pd.read_csv("inventories.csv")
# inventory_parts_df = pd.read_csv("inventory_parts.csv")

# %%
parts_df = parts_df.drop_duplicates()
parts_df = parts_df[
    parts_df["part_num"].notna() &
    parts_df["name"].notna()
]
parts_df["part_num"] = parts_df["part_num"].astype(str)
lego_parts = parts_df[["part_num", "name"]]

# %%
# lego_parts

# %%
# Training image counts
train_1  = len(os.listdir(os.path.join(train_dir, '2357 Brick corner 1x2x2')))
train_2  = len(os.listdir(os.path.join(train_dir, '2420 plate corner 2x2')))
train_3  = len(os.listdir(os.path.join(train_dir, '2780 Peg with friction')))
train_4  = len(os.listdir(os.path.join(train_dir, '3001 brick 2x4')))
train_5  = len(os.listdir(os.path.join(train_dir, '3002 brick 2x3')))
train_6  = len(os.listdir(os.path.join(train_dir, '3062 Round Brick 1x1')))
train_7  = len(os.listdir(os.path.join(train_dir, '3063 Curved Brick 2 Knobs')))
train_8  = len(os.listdir(os.path.join(train_dir, '3068 flat tile 2x2')))
train_9  = len(os.listdir(os.path.join(train_dir, '3069 Flat Tile 1x2')))
train_10 = len(os.listdir(os.path.join(train_dir, '3070 Flat Tile 1x1')))
train_11 = len(os.listdir(os.path.join(train_dir, '3003 Brick 2x2')))
train_12 = len(os.listdir(os.path.join(train_dir, '3298 roof tile 2x3')))
train_13 = len(os.listdir(os.path.join(train_dir, '3004 Brick 1x2')))
train_14 = len(os.listdir(os.path.join(train_dir, '3005 Brick 1x1')))
train_15 = len(os.listdir(os.path.join(train_dir, '3010 brick 1x4')))
train_16 = len(os.listdir(os.path.join(train_dir, '3020 plate 2x4')))
train_17 = len(os.listdir(os.path.join(train_dir, '3021 plate 2x3')))
train_18 = len(os.listdir(os.path.join(train_dir, '3022 Plate 2x2')))
train_19 = len(os.listdir(os.path.join(train_dir, '3023 Plate 1x2')))
train_20 = len(os.listdir(os.path.join(train_dir, '3024 Plate 1x1')))
train_21 = len(os.listdir(os.path.join(train_dir, '3037 roof tile 1x4')))
train_22 = len(os.listdir(os.path.join(train_dir, '3038 roof tile 2x3')))
train_23 = len(os.listdir(os.path.join(train_dir, '3039 roof tile 2x2')))
train_24 = len(os.listdir(os.path.join(train_dir, '3040 Roof Tile 1x2x45deg')))
train_25 = len(os.listdir(os.path.join(train_dir, '3045 roof corner outside tile 2x2')))
train_26 = len(os.listdir(os.path.join(train_dir, '3046 roof corner inside tile 2x2')))
train_27 = len(os.listdir(os.path.join(train_dir, '3622 brick 1x3')))
train_28 = len(os.listdir(os.path.join(train_dir, '3623 Plate 1x3')))
train_29 = len(os.listdir(os.path.join(train_dir, '3659 brick bow 1x4')))
train_30 = len(os.listdir(os.path.join(train_dir, '3675 roof tile outside 3x3')))
train_31 = len(os.listdir(os.path.join(train_dir, '3700 Technic Brick 1x2')))
train_32 = len(os.listdir(os.path.join(train_dir, '3794 Plate 1X2 with 1 Knob')))
train_33 = len(os.listdir(os.path.join(train_dir, '4150 flat tile round 2x2')))
train_34 = len(os.listdir(os.path.join(train_dir, '4274 Connector Peg w Knob')))
train_35 = len(os.listdir(os.path.join(train_dir, '4286 roof tile 1x3')))
train_36 = len(os.listdir(os.path.join(train_dir, '4490 brick bow 1x3')))
train_37 = len(os.listdir(os.path.join(train_dir, '6143 Brick D16 w cross')))
train_38 = len(os.listdir(os.path.join(train_dir, '6632 Technic Lever 3M')))
train_39 = len(os.listdir(os.path.join(train_dir, '14719 flat tile corner 2x2')))
train_40 = len(os.listdir(os.path.join(train_dir, '15672 roof tile 1x2')))
train_41 = len(os.listdir(os.path.join(train_dir, '18654 beam 1M')))
train_42 = len(os.listdir(os.path.join(train_dir, '27925 flat tile round 2x2')))
train_43 = len(os.listdir(os.path.join(train_dir, '33909 plate 2 knobs 2x2')))
train_44 = len(os.listdir(os.path.join(train_dir, '41677 lever 2M')))
train_45 = len(os.listdir(os.path.join(train_dir, '41678 Cross Block Fork 2x2')))
train_46 = len(os.listdir(os.path.join(train_dir, '43093 Bush 2M friction - Cross axle')))
train_47 = len(os.listdir(os.path.join(train_dir, '43857 beam 1x2')))
train_48 = len(os.listdir(os.path.join(train_dir, '54200 roof tile 1x1')))
train_49 = len(os.listdir(os.path.join(train_dir, '85984 roof tile 1x2')))
train_50 = len(os.listdir(os.path.join(train_dir, '99301 roof tile inside 3x3')))

total_training_images = sum([
    train_1, train_2, train_3, train_4, train_5, train_6, train_7, train_8,
    train_9, train_10, train_11, train_12, train_13, train_14, train_15, train_16,
    train_17, train_18, train_19, train_20, train_21, train_22, train_23, train_24,
    train_25, train_26, train_27, train_28, train_29, train_30, train_31, train_32,
    train_33, train_34, train_35, train_36, train_37, train_38, train_39, train_40,
    train_41, train_42, train_43, train_44, train_45, train_46, train_47, train_48,
    train_49, train_50
])
print(f"Total training images: {total_training_images}")

# Validation image counts
val_1  = len(os.listdir(os.path.join(validation_dir, '2357 Brick corner 1x2x2')))
val_2  = len(os.listdir(os.path.join(validation_dir, '2420 plate corner 2x2')))
val_3  = len(os.listdir(os.path.join(validation_dir, '2780 Peg with friction')))
val_4  = len(os.listdir(os.path.join(validation_dir, '3001 brick 2x4')))
val_5  = len(os.listdir(os.path.join(validation_dir, '3002 brick 2x3')))
val_6  = len(os.listdir(os.path.join(validation_dir, '3062 Round Brick 1x1')))
val_7  = len(os.listdir(os.path.join(validation_dir, '3063 Curved Brick 2 Knobs')))
val_8  = len(os.listdir(os.path.join(validation_dir, '3068 flat tile 2x2')))
val_9  = len(os.listdir(os.path.join(validation_dir, '3069 Flat Tile 1x2')))
val_10 = len(os.listdir(os.path.join(validation_dir, '3070 Flat Tile 1x1')))
val_11 = len(os.listdir(os.path.join(validation_dir, '3003 Brick 2x2')))
val_12 = len(os.listdir(os.path.join(validation_dir, '3298 roof tile 2x3')))
val_13 = len(os.listdir(os.path.join(validation_dir, '3004 Brick 1x2')))
val_14 = len(os.listdir(os.path.join(validation_dir, '3005 Brick 1x1')))
val_15 = len(os.listdir(os.path.join(validation_dir, '3010 brick 1x4')))
val_16 = len(os.listdir(os.path.join(validation_dir, '3020 plate 2x4')))
val_17 = len(os.listdir(os.path.join(validation_dir, '3021 plate 2x3')))
val_18 = len(os.listdir(os.path.join(validation_dir, '3022 Plate 2x2')))
val_19 = len(os.listdir(os.path.join(validation_dir, '3023 Plate 1x2')))
val_20 = len(os.listdir(os.path.join(validation_dir, '3024 Plate 1x1')))
val_21 = len(os.listdir(os.path.join(validation_dir, '3037 roof tile 1x4')))
val_22 = len(os.listdir(os.path.join(validation_dir, '3038 roof tile 2x3')))
val_23 = len(os.listdir(os.path.join(validation_dir, '3039 roof tile 2x2')))
val_24 = len(os.listdir(os.path.join(validation_dir, '3040 Roof Tile 1x2x45deg')))
val_25 = len(os.listdir(os.path.join(validation_dir, '3045 roof corner outside tile 2x2')))
val_26 = len(os.listdir(os.path.join(validation_dir, '3046 roof corner inside tile 2x2')))
val_27 = len(os.listdir(os.path.join(validation_dir, '3622 brick 1x3')))
val_28 = len(os.listdir(os.path.join(validation_dir, '3623 Plate 1x3')))
val_29 = len(os.listdir(os.path.join(validation_dir, '3659 brick bow 1x4')))
val_30 = len(os.listdir(os.path.join(validation_dir, '3675 roof tile outside 3x3')))
val_31 = len(os.listdir(os.path.join(validation_dir, '3700 Technic Brick 1x2')))
val_32 = len(os.listdir(os.path.join(validation_dir, '3794 Plate 1X2 with 1 Knob')))
val_33 = len(os.listdir(os.path.join(validation_dir, '4150 flat tile round 2x2')))
val_34 = len(os.listdir(os.path.join(validation_dir, '4274 Connector Peg w Knob')))
val_35 = len(os.listdir(os.path.join(validation_dir, '4286 roof tile 1x3')))
val_36 = len(os.listdir(os.path.join(validation_dir, '4490 brick bow 1x3')))
val_37 = len(os.listdir(os.path.join(validation_dir, '6143 Brick D16 w cross')))
val_38 = len(os.listdir(os.path.join(validation_dir, '6632 Technic Lever 3M')))
val_39 = len(os.listdir(os.path.join(validation_dir, '14719 flat tile corner 2x2')))
val_40 = len(os.listdir(os.path.join(validation_dir, '15672 roof tile 1x2')))
val_41 = len(os.listdir(os.path.join(validation_dir, '18654 beam 1M')))
val_42 = len(os.listdir(os.path.join(validation_dir, '27925 flat tile round 2x2')))
val_43 = len(os.listdir(os.path.join(validation_dir, '33909 plate 2 knobs 2x2')))
val_44 = len(os.listdir(os.path.join(validation_dir, '41677 lever 2M')))
val_45 = len(os.listdir(os.path.join(validation_dir, '41678 Cross Block Fork 2x2')))
val_46 = len(os.listdir(os.path.join(validation_dir, '43093 Bush 2M friction - Cross axle')))
val_47 = len(os.listdir(os.path.join(validation_dir, '43857 beam 1x2')))
val_48 = len(os.listdir(os.path.join(validation_dir, '54200 roof tile 1x1')))
val_49 = len(os.listdir(os.path.join(validation_dir, '85984 roof tile 1x2')))
val_50 = len(os.listdir(os.path.join(validation_dir, '99301 roof tile inside 3x3')))

total_validation_images = sum([
    val_1,val_2,val_3,val_4,val_5,val_6,val_7,val_8,val_9,val_10,val_11,val_12,val_13,val_14,
    val_15,val_16,val_17,val_18,val_19,val_20,val_21,val_22,val_23,val_24,val_25,val_26,val_27,
    val_28,val_29,val_30,val_31,val_32,val_33,val_34,val_35,val_36,val_37,val_38,val_39,val_40,
    val_41,val_42,val_43,val_44,val_45,val_46,val_47,val_48,val_49,val_50
])
print(f"Total validation images: {total_validation_images}")

# %%
train_data = ImageDataGenerator(
    rescale = 1/255,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    shear_range = 0.1,
    zoom_range = 0.1, 
    horizontal_flip = True
)

val_data = ImageDataGenerator(
    rescale = 1/255
)

target_size = (150, 150)

train_generator = train_data.flow_from_directory(
    train_dir,
    target_size = target_size,
    batch_size = 32,
    class_mode = 'categorical'
)

classes = list(train_generator.class_indices.keys()) # ai generated

val_generator = val_data.flow_from_directory(
    validation_dir,
    target_size=target_size,
    batch_size=32,
    class_mode='categorical',
    classes=classes  # ai generated
)
train_generator.class_indices

# %%
model = Sequential()
model.add(Conv2D(
    filters = 32,
    kernel_size = (3,3),
    activation = 'relu',
    input_shape = (150, 150, 3)
))
model.add(MaxPooling2D(
    pool_size = (2,2)
))
model.add(Conv2D(
    filters = 48,
    kernel_size = (3,3),
    activation = 'relu',
    input_shape = (150, 150, 3)
))
model.add(MaxPooling2D(
    pool_size = (2,2)
))
model.add(Conv2D(
    filters = 128,
    kernel_size = (3, 3),
    activation = 'relu',
    input_shape = (150, 150, 3)
))
model.add(MaxPooling2D(
    pool_size = (2,2)
))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(
    units=128,
    activation='relu'
))
model.add(Dense(units=50, activation='softmax')
)

# %%
# Out:
# C:\Users\muadz\anaconda3\envs\tensorflow_env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 48)          │          13,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 48)          │               0 │
# ...

# %%
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
early_stopping = EarlyStopping(
    monitor = 'val_loss',
    patience = 5,
    restore_best_weights = True
)

# %%
history = model.fit(train_generator, epochs=20, validation_data=val_generator, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 618s 617ms/step - accuracy: 0.1411 - loss: 2.9193 - val_accuracy: 0.2501 - val_loss: 2.4414
# Epoch 2/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 488s 488ms/step - accuracy: 0.2288 - loss: 2.4875 - val_accuracy: 0.3275 - val_loss: 2.1270
# Epoch 3/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 350s 350ms/step - accuracy: 0.3038 - loss: 2.1859 - val_accuracy: 0.2562 - val_loss: 2.5265
# Epoch 4/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 423s 423ms/step - accuracy: 0.3671 - loss: 1.9548 - val_accuracy: 0.2167 - val_loss: 3.1288
# Epoch 5/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 494s 494ms/step - accuracy: 0.4075 - loss: 1.8068 - val_accuracy: 0.2505 - val_loss: 2.7484
# Epoch 6/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 479s 479ms/step - accuracy: 0.4492 - loss: 1.6679 - val_accuracy: 0.4069 - val_loss: 1.7997
# Epoch 7/20
#  264/1000 ━━━━━━━━━━━━━━━━━━━━ 3:58 325ms/step - accuracy: 0.4888 - loss: 1.5528

# %%
saved_model = model.save('lego_parts_identifier.keras')
